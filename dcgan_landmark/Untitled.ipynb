# %%
import pstats

# %%
stats = pstats.Stats('landmark1000.profile')

# %%
a = stats.print_stats()
# Out:
# Thu May  3 05:16:09 2018    landmark1000.profile
#
#          9414023526 function calls (9403980865 primitive calls) in 47813.070 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     21800    0.024    0.000    0.024    0.000 /home/mil/kanayama/.pyenv/versions/anaconda3-4.0.0/envs/cuda9/lib/python3.6/site-packages/chainer/serializers/npz.py:38(__init__)
#     50000    0.221    0.000   15.125    0.000 /home/mil/kanayama/.pyenv/versions/anaconda3-4.0.0/envs/cuda9/lib/python3.6/site-packages/chainer/serializers/npz.py:46(__call__)
#     21200    0.053    0.000    0.089    0.000 /home/mil/kanayama/.pyenv/versions/anaconda3-4.0.0/envs/cuda9/lib/python3.6/site-packages/chainer/serializers/npz.py:42(__getitem__)
#       600    0.009    0.000   17.019    0.028 /home/mil/kanayama/.pyenv/versions/anaconda3-4.0.0/envs/cuda9/lib/python3.6/site-packages/chainer/serializer.py:58(save)
# ...

# %%
# Out:
# pstats.Stats
